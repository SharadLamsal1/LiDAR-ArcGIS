# %%
'''#Considering several mnumber of targets for pairs each observer 4 and 5: More than for 2 and 3.
This for observer pair target number - 4.
Observer  - 38.86895020107385, -77.23223381995975
Targets - 38.869143330934904, -77.23315717334442
38.86910515321332, -77.23303692090343
38.86908970032022, -77.23298555092865
38.869078792393644, -77.23294468844871
38.869062059058635, -77.23286795693015
38.869031747947574, -77.23279540340481
38.869024859056886, -77.23277593782483
38.869005570159445, -77.23271400188857
38.86898490347781, -77.23264498755958
38.868980770140745, -77.23263790916687
38.86896837012816, -77.23260605639965
38.86894494787626, -77.23251934608886
38.86893943675705, -77.23250872849978
38.86892703673725, -77.23249634131254
38.8689022366891, -77.23242024858673
38.86889259222439, -77.23233530787414

For pair 5: Observer: 38.870047, -77.232825
Targets:38.87088521605662, -77.23265452066117
38.87083823004199, -77.232690730487
38.870787240681636, -77.2327130842728
38.87074453060345, -77.23273431945096
38.87068666529532, -77.2327714810127
38.87061640021496, -77.23279625538721
38.870639821913834, -77.23278917699513
38.87055026830888, -77.2328157209678
38.87051169133344, -77.23283341694946
38.87041662656237, -77.23287057851122
38.870368405253075, -77.23289004409119
38.870331205934995, -77.23291127926935
38.870314672898495, -77.2329148184657
38.8702733402899, -77.23294313203631
38.870241651940745, -77.23295551922357
38.8702168523533, -77.23296436721445
38.87020445255634, -77.23297852399989
38.87020445255634, -77.23297852399989
38.87018378622326, -77.2329856023926






#targets for 2
#38.869330738339485, -77.23376469489178
#38.86927490799122, -77.23358403304059
#38.86920326374063, -77.23340353402634
#38.869130241639404, -77.2331398638938
#38.86908753056563, -77.2329629040759
#38.8690489527995, -77.23286911537241

# Format: (name, (observer_lat, observer_lon), (target_lat, target_lon))
    ("1_SDR", (38.86922736835016, -77.23329317992511), (38.87008408808786, -77.23302603408561)),
    ("1_SDL", (38.86922736835016, -77.23329317992511), (38.86983618518969, -77.23315513436673)),

    ("2_SDR", (38.86922736835016, -77.23329317992511), (38.86966051268562, -77.23323847646745)),
    ("2_SDL", (38.86922736835016, -77.23329317992511), (38.869598789806034, -77.2332750656832)),

    ("3_SDR", (38.86922736835016, -77.23329317992511), (38.869408872932134, -77.23334824411313)),
    ("3_SDL", (38.86922736835016, -77.23329317992511), (38.86931707959452, -77.23338483332809)),

    ("4_SDR", (38.86922736835016, -77.23329317992511), (38.86929510001497, -77.23341713842987)),
   
#2from here

    ("4_SDL", (38.869131257699586, -77.23279250838289), (38.869330738339485, -77.23376469489178)),

    ("5_SDR", (38.869131257699586, -77.23279250838289), (38.86927490799122, -77.23358403304059)),
    ("5_SDL", (38.869131257699586, -77.23279250838289), (38.86920326374063, -77.23340353402634)),

    ("6_SDR", (38.869131257699586, -77.23279250838289), (38.869130241639404, -77.2331398638938)),
    ("6_SDL", (38.869131257699586, -77.23279250838289), (38.86908753056563, -77.2329629040759)),

    ("7_SDR", (38.869131257699586, -77.23279250838289), (38.8690489527995, -77.23286911537241)),
    


import arcpy


# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters * 3.28084

# Observer and target coordinate pairs (name, observer, target)
observer_target_pairs = [
    # Format: (name, (observer_lat, observer_lon), (target_lat, target_lon))
    ("1_SDR", (38.86922736835016, -77.23329317992511), (38.87008408808786, -77.23302603408561)),
    ("1_SDL", (38.86922736835016, -77.23329317992511), (38.86983618518969, -77.23315513436673)),

    ("2_SDR", (38.86922736835016, -77.23329317992511), (38.86966051268562, -77.23323847646745)),
    ("2_SDL", (38.86922736835016, -77.23329317992511), (38.869598789806034, -77.2332750656832)),

    ("3_SDR", (38.86922736835016, -77.23329317992511), (38.869408872932134, -77.23334824411313)),
    ("3_SDL", (38.86922736835016, -77.23329317992511), (38.86931707959452, -77.23338483332809)),

    ("4_SDR", (38.86922736835016, -77.23329317992511), (38.86929510001497, -77.23341713842987)),


    ("4_SDL", (38.869131257699586, -77.23279250838289), (38.869330738339485, -77.23376469489178)),

    ("5_SDR", (38.869131257699586, -77.23279250838289), (38.86927490799122, -77.23358403304059)),
    ("5_SDL", (38.869131257699586, -77.23279250838289), (38.86920326374063, -77.23340353402634)),

    ("6_SDR", (38.869131257699586, -77.23279250838289), (38.869130241639404, -77.2331398638938)),
    ("6_SDL", (38.869131257699586, -77.23279250838289), (38.86908753056563, -77.2329629040759)),

    ("7_SDR", (38.869131257699586, -77.23279250838289), (38.8690489527995, -77.23286911537241)),
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    # Define unique names for each pair
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),  # Observer point
                arcpy.Point(tar_lon, tar_lat, target_height)  # Target point
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool using the DSM as input surface
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results (TarIsVis and Shape_Length fields)
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = meters_to_feet(row[1])
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract first obstruction point distance (if obstructed)
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)

                # Project both points to the obstruction spatial reference
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)

                # Compute distance in feet
                first_obstruction_distance_ft = meters_to_feet(observer_projected.distanceTo(obstruction_projected))
                break

        # Update result with obstruction distance
        visibility_results[-1] = (name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Analysis Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ LOS Analysis Complete. Results stored in your ArcGIS workspace.")

    '''

# %%
#actual changed code than earlier to incorporate one observer and multiple targets.
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

# Fixed observer location
observer = (38.86895020107385, -77.23223381995975)

# List of 16 target coordinates
target_coords = [
    (38.869143330934904, -77.23315717334442),
    (38.86910515321332, -77.23303692090343),
    (38.86908970032022, -77.23298555092865),
    (38.869078792393644, -77.23294468844871),
    (38.869062059058635, -77.23286795693015),
    (38.869031747947574, -77.23279540340481),
    (38.869024859056886, -77.23277593782483),
    (38.869005570159445, -77.23271400188857),
    (38.86898490347781, -77.23264498755958),
    (38.868980770140745, -77.23263790916687),
    (38.86896837012816, -77.23260605639965),
    (38.86894494787626, -77.23251934608886),
    (38.86893943675705, -77.23250872849978),
    (38.86892703673725, -77.23249634131254),
    (38.8689022366891, -77.23242024858673),
    (38.86889259222439, -77.23233530787414)
]

# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# ▶️ Processing: T14
#
# ▶️ Processing: T15
#
# ▶️ Processing: T16
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 41.87 ft
# T1: Obstructed, LOS Length = 230.27 ft, First Obstruction at 35.43 ft
# T2: Obstructed, LOS Length = 41.74 ft
# T2: Obstructed, LOS Length = 193.78 ft, First Obstruction at 35.21 ft
# T3: Obstructed, LOS Length = 41.62 ft
# T3: Obstructed, LOS Length = 178.36 ft, First Obstruction at 35.10 ft
# T4: Obstructed, LOS Length = 41.55 ft
# T4: Obstructed, LOS Length = 166.20 ft, First Obstruction at 35.06 ft
# T5: Obstructed, LOS Length = 41.79 ft
# T5: Obstructed, LOS Length = 143.29 ft, First Obstruction at 34.70 ft
# T6: Obstructed, LOS Length = 41.40 ft
# T6: Obstructed, LOS Length = 121.23 ft, First Obstruction at 34.58 ft
# T7: Obstructed, LOS Length = 38.44 ft
# T7: Obstructed, LOS Length = 118.28 ft, First Obstruction at 34.84 ft
# T8: Obstructed, LOS Length = 39.52 ft
# T8: Obstructed, LOS Length = 98.67 ft, First Obstruction at 34.24 ft
# T9: Obstructed, LOS Length = 45.15 ft
# T9: Obstructed, LOS Length = 72.60 ft, First Obstruction at 33.45 ft
# T10: Obstructed, LOS Length = 43.83 ft
# T10: Obstructed, LOS Length = 71.76 ft, First Obstruction at 33.57 ft
# T11: Obstructed, LOS Length = 43.40 ft
# T11: Obstructed, LOS Length = 62.79 ft, First Obstruction at 33.34 ft
# T12: Obstructed, LOS Length = 37.75 ft
# T12: Obstructed, LOS Length = 43.56 ft, First Obstruction at 33.65 ft
# T13: Obstructed, LOS Length = 37.73 ft
# T13: Obstructed, LOS Length = 40.64 ft, First Obstruction at 34.46 ft
# T14: Visible, LOS Length = 46.77 ft
# T14: Visible, LOS Length = 28.45 ft
# T15: Visible, LOS Length = 55.88 ft
# T16: Visible, LOS Length = 35.71 ft
#
# ✅ Line of Sight analysis completed.

# %%
#actual changed code than earlier to incorporate one observer and multiple targets. point pair =5
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

# Fixed observer location
observer = (38.870047, -77.232825)

# List of 16 target coordinates
target_coords = [
    (38.87088521605662, -77.23265452066117),
    (38.87083823004199, -77.232690730487),
    (38.870787240681636, -77.2327130842728),
    (38.87074453060345, -77.23273431945096),
    (38.87068666529532, -77.2327714810127),
    (38.87061640021496, -77.23279625538721),
    (38.870639821913834, -77.23278917699513),
    (38.87055026830888, -77.2328157209678),
    (38.87051169133344, -77.23283341694946),
    (38.87041662656237, -77.23287057851122),
    (38.870368405253075, -77.23289004409119),
    (38.870331205934995, -77.23291127926935),
    (38.870314672898495, -77.2329148184657),
    (38.8702733402899, -77.23294313203631),
    (38.870241651940745, -77.23295551922357),
    (38.8702168523533, -77.23296436721445),
    (38.87020445255634, -77.23297852399989),
    (38.87020445255634, -77.23297852399989),
    (38.87018378622326, -77.2329856023926),
]


# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# ▶️ Processing: T14
#
# ▶️ Processing: T15
#
# ▶️ Processing: T16
#
# ▶️ Processing: T17
#
# ▶️ Processing: T18
#
# ▶️ Processing: T19
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 28.58 ft
# T1: Obstructed, LOS Length = 280.53 ft, First Obstruction at 38.85 ft
# T2: Obstructed, LOS Length = 29.14 ft
# T2: Obstructed, LOS Length = 261.55 ft, First Obstruction at 39.11 ft
# T3: Obstructed, LOS Length = 33.62 ft
# T3: Obstructed, LOS Length = 237.86 ft, First Obstruction at 38.90 ft
# T4: Obstructed, LOS Length = 29.76 ft
# T4: Obstructed, LOS Length = 225.59 ft, First Obstruction at 38.75 ft
# T5: Obstructed, LOS Length = 28.93 ft
# T5: Obstructed, LOS Length = 204.53 ft, First Obstruction at 39.36 ft
# T6: Visible, LOS Length = 80.99 ft
# T6: Visible, LOS Length = 126.55 ft
# T7: Obstructed, LOS Length = 36.91 ft
# T7: Obstructed, LOS Length = 179.24 ft, First Obstruction at 41.28 ft
# T8: Visible, LOS Length = 70.11 ft
# T8: Visible, LOS Length = 113.20 ft
# T9: Visible, LOS Length = 70.40 ft
# T9: Visible, LOS Length = 98.86 ft
# T10: Visible, LOS Length = 86.28 ft
# T10: Visible, LOS Length = 48.96 ft
# T11: Visible, LOS Length = 78.56 ft
# T11: Visible, LOS Length = 39.95 ft
# T12: Visible, LOS Length = 68.30 ft
# T12: Visible, LOS Length = 38.08 ft
# T13: Visible, LOS Length = 66.43 ft
# T13: Visible, LOS Length = 34.35 ft
# T14: Visible, LOS Length = 71.33 ft
# T14: Visible, LOS Length = 17.70 ft
# T15: Visible, LOS Length = 80.04 ft
# T16: Visible, LOS Length = 73.49 ft
# T17: Visible, LOS Length = 72.10 ft
# T18: Visible, LOS Length = 72.10 ft
# T19: Visible, LOS Length = 67.62 ft
#
# ✅ Line of Sight analysis completed.

# %%
'''
Observer: 38.870818351528165, -77.23245095581497
Targets for observer target pair 6
38.871659401365285, -77.23229592417736
38.87160493415959, -77.23232505646884
38.87155961000776, -77.23234536379613
38.87150058426907, -77.23238031688703
38.87145967137985, -77.23239783138152
38.8714187706418, -77.2324153189662
38.8713414786838, -77.23245615283257
38.871245925666734, -77.2324911491412
38.87123387170175, -77.23250006477099
38.87110411266195, -77.23257020688538
38.870999210427726, -77.23261411790682
38.87100841157228, -77.23261995362682
38.87095817330733, -77.23262875925069
38.87093529147927, -77.23264342380772
'''
#actual changed code than earlier to incorporate one observer and multiple targets. point pair =6
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

# Fixed observer location
observer = (38.870818351528165, -77.23245095581497)

# List of target coordinates
target_coords = [
    (38.871659401365285, -77.23229592417736),
    (38.87160493415959, -77.23232505646884),
    (38.87155961000776, -77.23234536379613),
    (38.87150058426907, -77.23238031688703),
    (38.87145967137985, -77.23239783138152),
    (38.8714187706418, -77.2324153189662),
    (38.8713414786838, -77.23245615283257),
    (38.871245925666734, -77.2324911491412),
    (38.87123387170175, -77.23250006477099),
    (38.87110411266195, -77.23257020688538),
    (38.870999210427726, -77.23261411790682),
    (38.87100841157228, -77.23261995362682),
    (38.87095817330733, -77.23262875925069),
    (38.87093529147927, -77.23264342380772)
]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# ▶️ Processing: T14
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 26.78 ft
# T1: Obstructed, LOS Length = 282.69 ft, First Obstruction at 20.90 ft
# T2: Obstructed, LOS Length = 26.79 ft
# T2: Obstructed, LOS Length = 261.92 ft, First Obstruction at 20.91 ft
# T3: Obstructed, LOS Length = 26.86 ft
# T3: Obstructed, LOS Length = 244.77 ft, First Obstruction at 20.91 ft
# T4: Obstructed, LOS Length = 26.71 ft
# T4: Obstructed, LOS Length = 222.57 ft, First Obstruction at 20.94 ft
# T5: Obstructed, LOS Length = 26.66 ft
# T5: Obstructed, LOS Length = 207.39 ft, First Obstruction at 21.03 ft
# T6: Obstructed, LOS Length = 26.99 ft
# T6: Obstructed, LOS Length = 191.92 ft, First Obstruction at 21.65 ft
# T7: Obstructed, LOS Length = 34.33 ft
# T7: Obstructed, LOS Length = 156.20 ft, First Obstruction at 38.30 ft
# T8: Obstructed, LOS Length = 46.10 ft
# T8: Obstructed, LOS Length = 110.04 ft, First Obstruction at 41.01 ft
# T9: Obstructed, LOS Length = 57.42 ft
# T9: Obstructed, LOS Length = 94.56 ft, First Obstruction at 126.18 ft
# T10: Obstructed, LOS Length = 61.88 ft
# T10: Obstructed, LOS Length = 47.59 ft, First Obstruction at 82.78 ft
# T11: Obstructed, LOS Length = 74.63 ft
# T11: Obstructed, LOS Length = 5.97 ft, First Obstruction at 64.76 ft
# T12: Obstructed, LOS Length = 72.67 ft
# T12: Obstructed, LOS Length = 11.63 ft, First Obstruction at 65.10 ft
# T13: Obstructed, LOS Length = 65.82 ft
# T13: Obstructed, LOS Length = 5.98 ft, First Obstruction at 64.17 ft
# T14: Visible, LOS Length = 66.49 ft
# T14: Visible, LOS Length = 2.91 ft
#
# ✅ Line of Sight analysis completed.

# %%
#actual changed code than earlier to incorporate one observer and multiple targets. point pair =7
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.873428, -77.231198)

# List of target coordinates for Group 7
target_coords = [
    (38.874278944666415, -77.23149598977099),
    (38.87423540622084, -77.2314927454523),
    (38.87415316900854, -77.23149658052799),
    (38.87409167190633, -77.23153296178076),
    (38.87399459108172, -77.2315263994781),
    (38.873958947238584, -77.23153910553177),
    (38.87381185649874, -77.23151031516547),
    (38.87376467290642, -77.23151434587535),
    (38.87371409166105, -77.23149654055186),
    (38.87355857537899, -77.23150398589226),
    (38.873551808432474, -77.2314996902785),
    (38.87348743066684, -77.23150364601976),
]




# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 85.51 ft
# T1: Obstructed, LOS Length = 235.80 ft, First Obstruction at 27.72 ft
# T2: Obstructed, LOS Length = 77.45 ft
# T2: Obstructed, LOS Length = 228.34 ft, First Obstruction at 28.22 ft
# T3: Obstructed, LOS Length = 85.92 ft
# T3: Obstructed, LOS Length = 191.52 ft, First Obstruction at 29.75 ft
# T4: Obstructed, LOS Length = 145.42 ft
# T4: Obstructed, LOS Length = 114.42 ft, First Obstruction at 118.52 ft
# T5: Obstructed, LOS Length = 144.59 ft
# T5: Obstructed, LOS Length = 81.95 ft, First Obstruction at 137.32 ft
# T6: Obstructed, LOS Length = 147.60 ft
# T6: Obstructed, LOS Length = 68.79 ft, First Obstruction at 135.38 ft
# T7: Obstructed, LOS Length = 130.10 ft
# T7: Obstructed, LOS Length = 35.58 ft, First Obstruction at 114.27 ft
# T8: Obstructed, LOS Length = 122.31 ft
# T8: Obstructed, LOS Length = 29.83 ft, First Obstruction at 101.44 ft
# T9: Obstructed, LOS Length = 113.55 ft
# T9: Obstructed, LOS Length = 20.92 ft, First Obstruction at 86.36 ft
# T10: Obstructed, LOS Length = 81.73 ft
# T10: Obstructed, LOS Length = 17.51 ft, First Obstruction at 63.39 ft
# T11: Obstructed, LOS Length = 82.31 ft
# T11: Obstructed, LOS Length = 14.70 ft, First Obstruction at 63.00 ft
# T12: Obstructed, LOS Length = 77.71 ft
# T12: Obstructed, LOS Length = 11.96 ft, First Obstruction at 58.53 ft
#
# ✅ Line of Sight analysis completed.

# %%
#for group one SDL:
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.86922736835016, -77.23329317992511)

target_coords = [
    (38.86863551869054, -77.23378576747125),
    (38.86871908882119, -77.23373298445226),
    (38.868775857129144, -77.23370501661184),
    (38.868812987751184, -77.23368370713375),
    (38.86885852768716, -77.23366319442893),
    (38.86890107520958, -77.23364055967045),
    (38.868969412006784, -77.23359388503438),
    (38.86903330944513, -77.23354911874033),
    (38.86908614385164, -77.23351302931829),
    (38.86914554514723, -77.23348062069411),
]




# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 37.01 ft
# T1: Obstructed, LOS Length = 220.15 ft, First Obstruction at 23.76 ft
# T2: Obstructed, LOS Length = 38.49 ft
# T2: Obstructed, LOS Length = 185.00 ft, First Obstruction at 23.84 ft
# T3: Obstructed, LOS Length = 37.93 ft
# T3: Obstructed, LOS Length = 164.04 ft, First Obstruction at 24.21 ft
# T4: Obstructed, LOS Length = 37.85 ft
# T4: Obstructed, LOS Length = 149.60 ft, First Obstruction at 24.46 ft
# T5: Obstructed, LOS Length = 37.10 ft
# T5: Obstructed, LOS Length = 133.62 ft, First Obstruction at 25.13 ft
# T6: Obstructed, LOS Length = 33.34 ft
# T6: Obstructed, LOS Length = 121.27 ft, First Obstruction at 25.65 ft
# T7: Obstructed, LOS Length = 29.56 ft
# T7: Obstructed, LOS Length = 97.55 ft, First Obstruction at 26.62 ft
# T8: Obstructed, LOS Length = 36.22 ft
# T8: Obstructed, LOS Length = 65.30 ft, First Obstruction at 43.38 ft
# T9: Visible, LOS Length = 42.94 ft
# T9: Visible, LOS Length = 38.08 ft
# T10: Visible, LOS Length = 57.60 ft
# T10: Visible, LOS Length = 3.52 ft
#
# ✅ Line of Sight analysis completed.

# %%
#for group 2 SDL:
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.869131257699586, -77.23279250838289)

target_coords = [
    (38.86880177137197, -77.23199146257551),
    (38.86886004608882, -77.23215189210762),
    (38.86887454667444, -77.23219989271007),
    (38.868895167379705, -77.23227980235689),
    (38.868945152704114, -77.23240832438304),
    (38.86898882539173, -77.23256927320566),
    (38.869003391486885, -77.23264463273163),
    (38.86904744078726, -77.23275529452616),
    (38.86904743771647, -77.232787753621),
    (38.86904895744421, -77.23277530383533),
    (38.869074089636165, -77.23283201050056),
]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 20.95 ft
# T1: Obstructed, LOS Length = 236.76 ft, First Obstruction at 10.65 ft
# T2: Obstructed, LOS Length = 20.71 ft
# T2: Obstructed, LOS Length = 186.71 ft, First Obstruction at 11.21 ft
# T3: Obstructed, LOS Length = 20.74 ft
# T3: Obstructed, LOS Length = 172.16 ft, First Obstruction at 11.23 ft
# T4: Obstructed, LOS Length = 20.79 ft
# T4: Obstructed, LOS Length = 148.63 ft, First Obstruction at 11.53 ft
# T5: Obstructed, LOS Length = 20.94 ft
# T5: Obstructed, LOS Length = 107.74 ft, First Obstruction at 11.89 ft
# T6: Obstructed, LOS Length = 26.37 ft
# T6: Obstructed, LOS Length = 55.67 ft, First Obstruction at 18.40 ft
# T7: Obstructed, LOS Length = 21.53 ft
# T7: Obstructed, LOS Length = 41.24 ft, First Obstruction at 24.20 ft
# T8: Obstructed, LOS Length = 23.50 ft
# T8: Obstructed, LOS Length = 8.81 ft, First Obstruction at 17.92 ft
# T9: Visible, LOS Length = 30.56 ft
# T10: Visible, LOS Length = 30.37 ft
# T11: Visible, LOS Length = 23.66 ft
#
# ✅ Line of Sight analysis completed.

# %%
#For pair 3 SDR:
'''
Observer: 38.868401296315014, -77.23392957904841
Targets:  38.868029729161286, -77.2345977852378
    38.8681286977411, -77.23456749328575
    38.868240837340785, -77.23452417649725
    38.86830247832202, -77.23450639052439
    38.86836574604561, -77.23442913394439
    38.868365752674585, -77.23437560880717
    38.86836732095253, -77.23434186264991
    38.86835033572563, -77.23428237097127
    38.86833951097945, -77.23422696194471
    38.868330241226914, -77.23417951835481
    38.86832252904276, -77.23417752959132
    38.86831789953025, -77.23416569420264
    38.868308645130696, -77.2341184080458
    38.86827012769783, -77.23406111657005
    


'''
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.868401296315014, -77.23392957904841)

target_coords = [
    (38.868029729161286, -77.2345977852378),
    (38.8681286977411, -77.23456749328575),
    (38.868240837340785, -77.23452417649725),
    (38.86830247832202, -77.23450639052439),
    (38.86836574604561, -77.23442913394439),
    (38.868365752674585, -77.23437560880717),
    (38.86836732095253, -77.23434186264991),
    (38.86835033572563, -77.23428237097127),
    (38.86833951097945, -77.23422696194471),
    (38.868330241226914, -77.23417951835481),
    (38.86832252904276, -77.23417752959132),
    (38.86831789953025, -77.23416569420264),
    (38.868308645130696, -77.2341184080458),
    (38.86827012769783, -77.23406111657005),
]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# ▶️ Processing: T14
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 77.47 ft
# T1: Obstructed, LOS Length = 156.01 ft, First Obstruction at 91.64 ft
# T2: Obstructed, LOS Length = 82.65 ft
# T2: Obstructed, LOS Length = 124.34 ft, First Obstruction at 97.73 ft
# T3: Obstructed, LOS Length = 95.40 ft
# T3: Obstructed, LOS Length = 83.69 ft, First Obstruction at 113.78 ft
# T4: Visible, LOS Length = 109.32 ft
# T4: Visible, LOS Length = 58.81 ft
# T5: Visible, LOS Length = 80.89 ft
# T5: Visible, LOS Length = 61.93 ft
# T6: Visible, LOS Length = 71.81 ft
# T6: Visible, LOS Length = 55.84 ft
# T7: Visible, LOS Length = 68.11 ft
# T7: Visible, LOS Length = 49.93 ft
# T8: Obstructed, LOS Length = 64.76 ft
# T8: Obstructed, LOS Length = 37.39 ft, First Obstruction at 77.67 ft
# T9: Obstructed, LOS Length = 59.97 ft
# T9: Obstructed, LOS Length = 27.64 ft, First Obstruction at 65.64 ft
# T10: Obstructed, LOS Length = 62.80 ft
# T10: Obstructed, LOS Length = 12.92 ft, First Obstruction at 67.95 ft
# T11: Obstructed, LOS Length = 63.20 ft
# T11: Obstructed, LOS Length = 13.01 ft, First Obstruction at 61.46 ft
# T12: Obstructed, LOS Length = 61.59 ft
# T12: Obstructed, LOS Length = 12.18 ft, First Obstruction at 57.39 ft
# T13: Obstructed, LOS Length = 57.70 ft
# T13: Obstructed, LOS Length = 5.77 ft, First Obstruction at 52.82 ft
# T14: Obstructed, LOS Length = 54.92 ft
# T14: Obstructed, LOS Length = 5.78 ft, First Obstruction at 45.22 ft
#
# ✅ Line of Sight analysis completed.

# %%
#3SDL:
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.868401296315014, -77.23392957904841)

target_coords = [
    (38.86774368899713, -77.23335362494895),
    (38.867819710203975, -77.23339629692231),
    (38.86791153440867, -77.23346518390979),
    (38.86799344137443, -77.23353263714652),
    (38.86805368690196, -77.23358396840823),
    (38.86808478923127, -77.23362622542292),
    (38.8681250630978, -77.23368493931572),
    (38.868158045121056, -77.2337154653895),
    (38.86816539505823, -77.23374602502788),
    (38.86819475298048, -77.2337718934584),
    (38.868211256210465, -77.23380485284663),
    (38.86824433393896, -77.23385902926583),
    (38.86828308050687, -77.23392748494038),
]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# 🔹 Line of Sight Results (in feet):
# T1: Visible, LOS Length = 221.72 ft
# T1: Visible, LOS Length = 68.54 ft
# T2: Visible, LOS Length = 183.50 ft
# T2: Visible, LOS Length = 77.11 ft
# T3: Visible, LOS Length = 140.00 ft
# T3: Visible, LOS Length = 82.04 ft
# T4: Visible, LOS Length = 88.91 ft
# T4: Visible, LOS Length = 97.74 ft
# T5: Obstructed, LOS Length = 55.76 ft
# T5: Obstructed, LOS Length = 104.59 ft, First Obstruction at 154.24 ft
# T6: Visible, LOS Length = 59.07 ft
# T6: Visible, LOS Length = 84.97 ft
# T7: Visible, LOS Length = 59.24 ft
# T7: Visible, LOS Length = 63.12 ft
# T8: Visible, LOS Length = 52.48 ft
# T8: Visible, LOS Length = 55.06 ft
# T9: Visible, LOS Length = 72.51 ft
# T9: Visible, LOS Length = 28.05 ft
# T10: Visible, LOS Length = 62.03 ft
# T10: Visible, LOS Length = 25.57 ft
# T11: Visible, LOS Length = 62.68 ft
# T11: Visible, LOS Length = 15.11 ft
# T12: Visible, LOS Length = 57.68 ft
# T12: Visible, LOS Length = 2.91 ft
# T13: Visible, LOS Length = 43.06 ft
#
# ✅ Line of Sight analysis completed.

# %%
#Pair4 SDL
import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.86895020107385, -77.23223381995975)

target_coords = [
    (38.86873885924426, -77.23132869210396),
    (38.86871202753149, -77.23145976864103),
    (38.86869752319321, -77.23152622864224),
    (38.8686870927345, -77.23158443607876),
    (38.86870777299527, -77.23167475153902),
    (38.868730481746944, -77.23174890054526),
    (38.868749072313236, -77.23182848920166),
    (38.86878017437892, -77.23194030729083),
    (38.86880094717662, -77.23201768838211),
    (38.868809254055414, -77.23202303400852),
    (38.8688300104638, -77.23210299586249),
    (38.86885285073416, -77.23216963428087),
    (38.868863239012434, -77.23222563782281),
    (38.86888403986542, -77.23227900817925),
]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
#
# ▶️ Processing: T4
#
# ▶️ Processing: T5
#
# ▶️ Processing: T6
#
# ▶️ Processing: T7
#
# ▶️ Processing: T8
#
# ▶️ Processing: T9
#
# ▶️ Processing: T10
#
# ▶️ Processing: T11
#
# ▶️ Processing: T12
#
# ▶️ Processing: T13
#
# ▶️ Processing: T14
#
# 🔹 Line of Sight Results (in feet):
# T1: Obstructed, LOS Length = 41.84 ft
# T1: Obstructed, LOS Length = 227.12 ft, First Obstruction at 38.97 ft
# T2: Visible, LOS Length = 103.41 ft
# T2: Visible, LOS Length = 133.44 ft
# T3: Visible, LOS Length = 113.23 ft
# T3: Visible, LOS Length = 108.25 ft
# T4: Visible, LOS Length = 99.26 ft
# T4: Visible, LOS Length = 108.99 ft
# T5: Visible, LOS Length = 73.63 ft
# T5: Visible, LOS Length = 108.40 ft
# T6: Visible, LOS Length = 51.98 ft
# T6: Visible, LOS Length = 107.60 ft
# T7: Obstructed, LOS Length = 40.67 ft
# T7: Obstructed, LOS Length = 96.02 ft, First Obstruction at 30.79 ft
# T8: Obstructed, LOS Length = 38.63 ft
# T8: Obstructed, LOS Length = 65.38 ft, First Obstruction at 26.72 ft
# T9: Obstructed, LOS Length = 32.26 ft
# T9: Obstructed, LOS Length = 49.85 ft, First Obstruction at 26.58 ft
# T10: Obstructed, LOS Length = 32.17 ft
# T10: Obstructed, LOS Length = 46.80 ft, First Obstruction at 26.78 ft
# T11: Visible, LOS Length = 32.01 ft
# T11: Visible, LOS Length = 25.47 ft
# T12: Visible, LOS Length = 31.03 ft
# T12: Visible, LOS Length = 8.86 ft
# T13: Visible, LOS Length = 31.76 ft
# T14: Visible, LOS Length = 27.32 ft
#
# ✅ Line of Sight analysis completed.

# %%
#Pair 5 SDL:

import arcpy

# Automatically detect the current ArcGIS Pro workspace
workspace = arcpy.env.workspace
if not workspace:
    raise Exception("Workspace is not set. Please specify an active workspace in ArcGIS Pro.")

arcpy.env.overwriteOutput = True  # Allow overwriting existing outputs

# Define input elevation surface (Digital Surface Model)
elevation_surface = "DSM_withground_build.tif"  # Ensure this DSM exists in your workspace

# Define observer and target height above the surface (3.5 feet = 1.07 meters)
observer_height = 1.07  # in meters
target_height = 1.07  # in meters

# Set spatial reference to WGS 84 (lat/lon)
spatial_ref_wgs84 = arcpy.SpatialReference(4326)  # EPSG:4326

# Set spatial reference to NAD 1983 (2011) UTM Zone 18N
spatial_ref_projected = arcpy.SpatialReference(26918)

# Convert meters to feet function
def meters_to_feet(meters):
    return meters 

observer = (38.870047, -77.232825)

target_coords = [
    (38.869339103045625, -77.23331403667311),
    (38.869400758114224, -77.23331054388069),
    (38.86949633915065, -77.23323848511363),
    (38.869567341559, -77.23323580290464),
    (38.869607019344514, -77.23320629860578),
    (38.86965713862091, -77.23315265442601),
    (38.869652962015884, -77.23315265442601),
    (38.869703081259885, -77.23313924338107),
    (38.8697490238692, -77.23312851454511),
    (38.86978870155332, -77.2330882814103),
    (38.86986179197067, -77.23304804827426),
    (38.86993905889676, -77.2330158617664),
    (38.86998082476777, -77.23298367525854),
    (38.87001841403071, -77.23297294642259),
    (38.87007270959763, -77.23295685316867),

]



# Build the observer-target pair list
observer_target_pairs = [
    (f"T{i+1}", observer, target) for i, target in enumerate(target_coords)
]

# Store LOS results
visibility_results = []

# Process each observer-target pair
for name, (obs_lat, obs_lon), (tar_lat, tar_lon) in observer_target_pairs:

    print(f"\n▶️ Processing: {name}")

    # Define unique names for output
    line_fc = f"LOS_Line_{name}"
    line_of_sight_fc = f"LOS_Results_{name}"
    obstruction_fc = f"Obstruction_{name}"

    # Create a new polyline feature class for the LOS line
    arcpy.management.CreateFeatureclass(workspace, line_fc, "POLYLINE", spatial_reference=spatial_ref_wgs84)

    # Insert observer-to-target line with elevation applied
    with arcpy.da.InsertCursor(line_fc, ["SHAPE@"]) as cursor:
        polyline = arcpy.Polyline(
            arcpy.Array([
                arcpy.Point(obs_lon, obs_lat, observer_height),
                arcpy.Point(tar_lon, tar_lat, target_height)
            ]),
            spatial_ref_wgs84
        )
        cursor.insertRow([polyline])

    # Run Line of Sight Tool
    arcpy.ddd.LineOfSight(
        in_surface=elevation_surface,
        in_line_feature_class=line_fc,
        out_los_feature_class=line_of_sight_fc,
        out_obstruction_feature_class=obstruction_fc,
        use_curvature="NO_CURVATURE",
        use_refraction="NO_REFRACTION",
        refraction_factor=0.13,
        pyramid_level_resolution=0
    )

    # Initialize obstruction distance variable
    first_obstruction_distance_ft = None  

    # Extract LOS results
    if arcpy.Exists(line_of_sight_fc):
        with arcpy.da.SearchCursor(line_of_sight_fc, ["TarIsVis", "Shape_Length"]) as cursor:
            for row in cursor:
                tar_is_visible = row[0]  # 0 = Obstructed, 1 = Visible
                shape_length_ft = row[1]  # Already in feet since surface is in feet
                visibility_results.append((name, tar_is_visible, shape_length_ft, first_obstruction_distance_ft))

    # Extract obstruction distance
    if arcpy.Exists(obstruction_fc):
        desc = arcpy.Describe(obstruction_fc)
        obstruction_spatial_ref = desc.spatialReference

        with arcpy.da.SearchCursor(obstruction_fc, ["SHAPE@"]) as cursor:
            for obstruction in cursor:
                obstruction_geom = obstruction[0]
                observer_geom = arcpy.PointGeometry(arcpy.Point(obs_lon, obs_lat), spatial_ref_wgs84)
                obstruction_projected = obstruction_geom.projectAs(obstruction_spatial_ref)
                observer_projected = observer_geom.projectAs(obstruction_spatial_ref)
                first_obstruction_distance_ft = observer_projected.distanceTo(obstruction_projected)
                break

        # Update result with obstruction distance
        if visibility_results:
            last = visibility_results[-1]
            visibility_results[-1] = (last[0], last[1], last[2], first_obstruction_distance_ft)

# Print LOS analysis results
if visibility_results:
    print("\n🔹 Line of Sight Results (in feet):")
    for name, tar_is_visible, shape_length_ft, obstruction_distance_ft in visibility_results:
        status = "Visible" if tar_is_visible == 1 else "Obstructed"
        obs_text = f", First Obstruction at {obstruction_distance_ft:.2f} ft" if obstruction_distance_ft else ""
        print(f"{name}: {status}, LOS Length = {shape_length_ft:.2f} ft{obs_text}")
else:
    print("⚠ No sight lines were generated.")

print("\n✅ Line of Sight analysis completed.")
# Out:
# ▶️ Processing: T1
#
# ▶️ Processing: T2
#
# ▶️ Processing: T3
